# %%
2.12

# Kita punya list warna
warna = ["merah", "hijau", "kuning", "biru", "pink", "ungu"]

# Kita potong dari indeks ke-4 sampai ke-5
print(warna[1:5])
# Out:
# ['hijau', 'kuning', 'biru', 'pink']

# %%
2.13 

# membuat list
hari = ["Senin", "Selasa", "Rabu", "Kamis"]

print(hari)

print(hari[:])

print(hari[1:])

print(hari[2:])

print(hari[1:2])
# Out:
# ['Senin', 'Selasa', 'Rabu', 'Kamis']
# ['Senin', 'Selasa', 'Rabu', 'Kamis']
# ['Selasa', 'Rabu', 'Kamis']
# ['Rabu', 'Kamis']
# ['Selasa']

# %%
2.14

angka = [1,2,3,4,5,6]

for a in angka:
    print(a)
    
# Output
1
2
3
4
5
6
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 6
